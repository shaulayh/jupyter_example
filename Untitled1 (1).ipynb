# %%
#!/usr/bin/env python
# coding: utf-8

# # The top two tribes in Nigeria
# **Igbo)** Known for vast knowledge of business and wealth
# 
# **Yoruba)** The most Educative and agriculturally rich tribe in Nigeria
# 
# # Some Cities to visit
# **Lagos** Former Capital and one of the most populous city in Africa
# 
# **Onitsha** One of the major trade hub of Africa and Nigeria
# 
# **Ibadan** The oldest City and biggest City in west Africa
#

# %%
import matplotlib.pyplot as plt
import numpy as np
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
x=[1,2,3,4,5,6,7,8,9]
y=[2,3,2,3,5,7,2,3,8]
y2=[1,2,5,4,6,4,6,7,3]

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.set_title('Plot Graph',fontsize=24)

ax.set_xlabel('-----x axis-----')
ax.set_ylabel('-----y axis-----')


plt.plot(x,y,label='curve1')
plt.plot(x,y2,label='curve1')

ax.legend()

# %%
200 * 5
# Out:
# 1000

# %%
print("Hello World")
# Out:
# Hello World
